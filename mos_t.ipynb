# %%
import librosa
import matplotlib.pyplot as plt
import soundfile as sf
import os
import pyttsx3

def evaluate_text_to_speech_system(text):
    # Initialize the pyttsx3 engine
    engine = pyttsx3.init()

    # Set the rate and volume of the speech
    engine.setProperty('rate', 150)
    engine.setProperty('volume', 1.0)

    # Convert text to speech
    engine.say(text)
    engine.runAndWait()

    # Get MOS score from user input
    mos_score = int(input("Please rate the audio quality on a scale of 1 to 5: "))

    return mos_score

text = "Hello, world!"
evaluate_text_to_speech_system(text)
def calculate_mos_score(audio_file):
    # Load audio file using librosa
    audio_data, sample_rate = librosa.load(audio_file, sr=None)

    # Play audio file using soundfile
    sf.play(audio_data, sample_rate)

    # Get MOS score from user input
    mos_score = int(input("Please rate the audio quality on a scale of 1 to 5: "))

    return mos_score

def evaluate_text_to_speech_system(text, lang="en", voice="en-us"):
    # Create a gTTS object with the text and language
    tts = gTTS(text=text, lang=lang, tld=voice)

    # Save the synthesized speech to a file
    tts.save("output.mp3")

    # Play the MP3 file using the default media player
    os.system("start output.mp3")

    # Calculate MOS score and intelligibility score for audio file
    mos_score = calculate_mos_score("output.mp3")

    # Print MOS score
    print("MOS score for audio file: ",mos_score)

    return mos_score

text = "who gives so less in open elective like oh my god this is so pissing off, we must ask which teachers are taking the classes. In the end, it all affects our CGPA. Oh my god I love this."
vo = "en-us"
evaluate_text_to_speech_system(text, vo)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File c:\Python311\Lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File c:\Python311\Lib\socket.py:962, in getaddrinfo(host, port, family, type, proto, flags)
#     961 addrlist = []
# ...
